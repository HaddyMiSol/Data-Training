# %% [markdown]
# # Introduction to Python Training

# %% [markdown]
# Python is a very high-level programming language because its syntax so closely resembles the English language. Higher-level means it’s more readable to humans and less readable to computers. Likewise, Lower-level means less readable for humans and more readable for computers.
#
# Some common use cases of Python includes —
#
# Web Applications, with Django, Flask, etc.
# Machine Learning, with SkLearn, PyTorch, etc.
# Data Analysis and Manipulation, with Pandas, SQL, etc.
# Cybersecurity, with Nmap, Yara, etc.
# There are a lot more uses cases of Python apart from these like Data scraping, testing, or scripting.

# %% [markdown]
# ![6af294a5e19e416faf22baf35c2aa7bbc3ce0859bdbcb9b48a7bbb19107b7c70.png](attachment:6af294a5e19e416faf22baf35c2aa7bbc3ce0859bdbcb9b48a7bbb19107b7c70.png)

# %% [markdown]
# ![3e136c21655beff45307ef1625c3dbcab29541cba8f83a538d08bdb133784eb7.png](attachment:3e136c21655beff45307ef1625c3dbcab29541cba8f83a538d08bdb133784eb7.png)

# %% [markdown]
# #### How to download anaconda  python, jupyter notebook
#
# - Go to [anaconda.com]("https://www.anaconda.com/") and click on download (download the most recent version)
# - After download, install the anaconda package and open it

# %% [markdown]
# ![c.png](attachment:c.png)

# %% [markdown]
# ![cc.png](attachment:cc.png)

# %% [markdown]
# ![cccc.png](attachment:cccc.png)

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ### Variables and Data Types

# %% [markdown]
# - Variable is like a container.
# - Data types; integer, float, boolean, string,list,tuple,None, Dictionary

# %%
a = 1.3
a
# Out:
# 1.3

# %%
b = 'good'
b
# Out:
# 'good'

# %%
type(a)
# Out:
# float

# %%
type(1)

# %%
type(2.4)
# Out:
# float

# %%
int(2.4)
# Out:
# 2

# %%
a = 2 + 5.6
a
# Out:
# 7.6

# %%
int(a)
# Out:
# 7

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
3 + True
# Out:
# 4

# %%
3 + False
# Out:
# 3

# %%
" " ' '

# %%
message = " I'm learning"

# %%
message_1 = "and I love it!"

# %%
message + message_1
# Out:
# " I'm learningand I love it!"

# %%
message + ' '+ message_1
# Out:
# " I'm learning and I love it!"

# %%
f'{message}'
# Out:
# " I'm learning"

# %%
new_message = message + ' '+ message_1
new_message

# %%
f'{message} {message_1}'
# Out:
# " I'm learning and I love it!"

# %%
type(message)
# Out:
# str

# %%
 b = 1
str(b)
# Out:
# '1'

# %%
b = 2.4
str(b)
# Out:
# '2.4'

# %%
type("man")
# Out:
# str

# %%
print("girl".lower())
print("girl".title())
print("Hello World".count('l'))

# %%
print("Hello World".count('l'))
# Out:
# 3

# %%
print("girl".title())
# Out:
# Girl

# %%
'today'.capitalize()
# Out:
# 'Today'

# %%
"Hello World".replace("o", "a")
# Out:
# 'Hella Warld'

# %%
gg = 'girlybaly'

# %%
print([*gg])
# Out:
# ['g', 'i', 'r', 'l', 'y', 'b', 'a', 'l', 'y']

# %%
gg.split('l')
# Out:
# ['gir', 'yba', 'y']

# %%
message.strip()
# Out:
# "I'm learning"

# %%
len("Hello World")
# Out:
# 11

# %%
str(21)
# Out:
# '21'

# %%
str(45.4)
# Out:
# '45.4'

# %%
a = 'John'

# %%
a == 'Doe'
# Out:
# False

# %%
a !='John'
# Out:
# False

# %%
cost_of_bag = 1000
No_of_bags_sold = 8
total_profit = cost_of_bag * No_of_bags_sold

profit = '''We sold {} bags at {} rate for each bag. Our total profit is {}'''

report = profit.format(No_of_bags_sold, cost_of_bag, total_profit)
print(report)
# Out:
# We sold 8 bags at 1000 rate for each bag. Our total profit is 8000

# %%
#indicates absence of value
nothing = None

# %%
type(nothing)
# Out:
# NoneType

# %% [markdown]
# ### Lists

# %%
[]

# %%
countries = ["USA", "India", "Brazil", "Nigeria", "Ghana"]

# %%
# Indexing(positive and negative)

countries[-1]

# %%
countries[-2]
# Out:
# 'Nigeria'

# %%
len(countries)
# Out:
# 5

# %%
# slicing

countries[0:2]
countries[2:]
countries[:3]

# %%
countries[0:2]
# Out:
# ['USA', 'India']

# %%
countries[2:]
# Out:
# ['Brazil', 'Nigeria', 'Ghana']

# %%
countries[:3]
# Out:
# ['USA', 'India', 'Brazil']

# %% [markdown]
# ##### Adding elements to a list

# %%
countries.append("Canada")
countries
# Out:
# ['USA', 'India', 'Brazil', 'Nigeria', 'Ghana', 'Canada']

# %%
countries.insert(1, 'Spain')

# %%
countries
# Out:
# ['USA', 'Spain', 'India', 'Brazil', 'Nigeria', 'Ghana', 'Canada']

# %%
countries_1 = ['UK', 'Austria']

# %%
new_country= countries + countries_1
new_country
# Out:
# ['USA',
#  'Spain',
#  'India',
#  'Brazil',
#  'Nigeria',
#  'Ghana',
#  'Canada',
#  'UK',
#  'Austria']

# %% [markdown]
# ##### Removing element fron a list

# %%
countries.remove("USA")
countries
# Out:
# ['Spain', 'India', 'Brazil', 'Nigeria', 'Ghana', 'Canada']

# %%
countries.pop(0)
countries
# Out:
# ['India', 'Brazil', 'Nigeria', 'Ghana', 'Canada']

# %%
countries.pop(-1)
# Out:
# 'Canada'

# %%
countries
# Out:
# ['India', 'Brazil', 'Nigeria', 'Ghana']

# %%
del countries[3]

# %%
countries
# Out:
# ['India', 'Brazil', 'Nigeria']

# %% [markdown]
# ##### sorting a list

# %%
numbers = [7,9,6,4,1,0]

# %%
numbers.sort()
numbers
# Out:
# [0, 1, 4, 6, 7, 9]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [9, 7, 6, 4, 1, 0]

# %% [markdown]
# #####  Update element

# %%
numbers[1] = 500

# %%
numbers
# Out:
# [9, 500, 6, 4, 1, 0]

# %% [markdown]
# ##### Copying a list

# %%
countries
# Out:
# ['India', 'Brazil', 'Nigeria']

# %%
new_country = countries[:]

# %%
new_country
# Out:
# ['India', 'Brazil', 'Nigeria']

# %%
new_country1=  countries.copy()

# %%
new_country1
# Out:
# ['India', 'Brazil', 'Nigeria']

# %% [markdown]
# ### Tuple

# %%
()

# %%
fruits = ("apple", "cherry", "mango")

# %%
len(fruits)
# Out:
# 3

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[0:2]
# Out:
# ('apple', 'cherry')

# %%
fruits[0] = "avocado"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14344/3316339456.py in <module>
# ----> 1 fruits[0] = "avocado"
#
# TypeError: 'tuple' object does not support item assignment

# %%
fruits.append("orange")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14344/1121117358.py in <module>
# ----> 1 fruits.append("orange")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
fruits.remove("cherry")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14344/2586446587.py in <module>
# ----> 1 fruits.remove("cherry")
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
 a = [1, 'gdh', 2.4, True]
a
# Out:
# [1, 'gdh', 2.4, True]

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# It is an unordered collection of items. Each value is represented or identified by a key

# %%
{}

# %%
my_dict ={"key1": "value1", "key2": "value2"}

# %%
data = {"name" : "Hadassah", "age" : 12, "length" : 2.3}

# %%
 a = {"name" : ['Alison', 'Jide', 'Haddy'], "age" : [12, 23, 34]}

# %%
a
# Out:
# {'name': ['Alison', 'Jide', 'Haddy'], 'age': [12, 23, 34]}

# %%
a['name'][2]
# Out:
# 'Haddy'

# %%
data
# Out:
# {'name': 'Hadassah', 'age': 12, 'length': 2.3}

# %%
data.keys()
# Out:
# dict_keys(['name', 'age', 'length'])

# %%
data.values()
# Out:
# dict_values(['Hadassah', 12, 2.3])

# %%
data.items()
# Out:
# dict_items([('name', 'Hadassah'), ('age', 12), ('length', 2.3)])

# %%
# add more data
data["height"] = 1.55

# %%
data
# Out:
# {'name': 'Hadassah', 'age': 12, 'length': 2.3, 'height': 1.55}

# %%
# update data
data.update({"height": 1.90})

# %%
data['name'] = 'Alison'

# %%
data
# Out:
# {'name': 'Alison', 'age': 12, 'length': 2.3, 'height': 1.9}

# %%
data['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14344/3640432609.py in <module>
# ----> 1 data['name'][0]
#
# KeyError: 'name'

# %%
data.get('name')
# Out:
# 'Alison'

# %%
data['married']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14344/3537578423.py in <module>
# ----> 1 data['married']
#
# KeyError: 'married'

# %%
data.get('married', 'Unknown')
# Out:
# 'Unknown'

# %%
'address' in data
# Out:
# False

# %%
# make a copy
new_data= data.copy()

# %%
new_data
# Out:
# {'name': 'Alison', 'age': 12, 'length': 2.3, 'height': 1.9}

# %%
# remove element
data.pop("age")
# Out:
# 12

# %%
data
# Out:
# {'name': 'Alison', 'length': 2.3, 'height': 1.9}

# %%
del data['name']

# %%
data
# Out:
# {'length': 2.3, 'height': 1.9}

# %%
data.clear()

# %%
data
# Out:
# {}

# %% [markdown]
# ### if statements

# %%
if <condition>:
    <statement>
elif <condition>:
    <statement>
....
else:
    <statement>

# %%
a_number = 31

# %%
if a_number % 2 == 0:
    print("even")
    print('The given number {} is even.'.format(a_number))
else:
    print("odd")
# Out:
# odd

# %%
age = 3

if age >= 18:
    print("Adult")
elif age >=13:
    print("Teenager")
else:
    print("kid")
# Out:
# kid

# %%
today = 'Monday'

# %%
if today == 'Sunday':
    print("Today is the day of the sun.")
elif today == 'Monday':
    print("Today is the day of the moon.")
elif today == 'Tuesday':
    print("Today is the day of Tyr, the god of war.")
elif today == 'Wednesday':
    print("Today is the day of Odin, the supreme diety.")
elif today == 'Thursday':
    print("Today is the day of Thor, the god of thunder.")
elif today == 'Friday':
    print("Today is the day of Frigga, the goddess of beauty.")
elif today == 'Saturday':
    print("Today is the day of Saturn, the god of fun and feasting.")
# Out:
# Today is the day of the moon.

# %%
a_number = 8

# %%
if a_number % 3 == 0 and a_number % 5 == 0:
    print("The number {} is divisible by 3 and 5".format(a_number))
elif not a_number % 5 == 0:
    print("The number {} is not divisible by 5".format(a_number))
# Out:
# The number 8 is not divisible by 5

# %%
a =1

# %%
if a == 1:
print('false')
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp/ipykernel_14344/3557457124.py", line 2
#     print('false')
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# #### Nested Conditional Statement

# %%
a_number = 17

# %%
if a_number % 2 == 0:
    print("{} is even".format(a_number))
    if a_number % 3 == 0:
        print("{} is also divisible by 3".format(a_number))
    else:
        print("{} is not divisible by 3".format(a_number))
else:
    print("{} is odd".format(a_number))
    if a_number % 5 == 0:
        print("{} is also divisible by 5".format(a_number))
    else:
        print("{} is not divisibule by 5".format(a_number))
# Out:
# 17 is odd
# 17 is not divisibule by 5

# %% [markdown]
# ##### using pass

# %%
a_number = 17

# %%
if a_number % 2 == 0:
    pass
elif a_number % 3 == 0:
    print('{} is divisible by 3 but not divisible by 2'.format(a_number))
else:
    print('not divisible by 2 and 3')
# Out:
# not divisible by 2 and 3

# %% [markdown]
# ### For loop

# %%
for <variable> in <iterables>:
    <code>

# %%
#looping through a list
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

for day in days:
    print(day)

# %%
# Looping through a string
for char in 'Monday':
    print(char)

# %%
# Looping over a tuple
for fruit in ('Apple', 'Banana', 'Guava'):
    print("Here's a fruit:", fruit)

# %%
# Looping over a dictionary
person = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

for key in person:
    print("Key:", key, ",", "Value:", person[key])

# %%
for value in person.values():
    print(value)

# %%
for key_value_pair in person.items():
    print(key_value_pair)

# %%
for key, value in person.items():
    print("Key:", key, ",", "Value:", value)

# %% [markdown]
# #### iterating using range and enumerate

# %%
for i in range(7):
    print(i)

# %%
for i in range(3, 10):
    print(i)

# %%
for i in range(3, 14, 4):
    print(i)

# %%
for i, day in enumerate(days):
    print(i, day)

# %% [markdown]
# #### While loop

# %%
result = 1
i = 1

while i <= 10:
    result = result * i
    i = i+1

print('The factorial of 10 is: {}'.format(result))

# %%
#Infinite loop

# %% [markdown]
# #### break and continue

# %%
i = 1
result = 1

while i <= 100:
    result *= i
    if i == 42:
        print('Magic number 42 reached! Stopping execution..')
        break
    i += 1
    
print('i:', i)
print('result:', result)

# %%
i = 1
result = 1

while i < 20:
    i += 1
    if i % 2 == 0:
        print('Skipping {}'.format(i))
        continue
    print('Multiplying with {}'.format(i))
    result = result * i
    
print('i:', i)
print('result:', result)

# %% [markdown]
# #### Nested for loop

# %%
days = ['Monday', 'Tuesday', 'Wednesday']
fruits = ['apple', 'banana', 'guava']

for day in days:
    for fruit in fruits:
        print(day, fruit)

# %% [markdown]
# ### Functions

# %%
def function(<params>):
    <code>
    return <data>

# %%
def say_hello():
    print("Hello there")
    print("How are you?")

# %%
def sum_value(a,b):
    x = a+b
    return x

# %%
sum_values(,)

# %%
def even_number(num_list):
    result = []
    for num in num_list:
        if num % 2 ==0:
            result.append(num)
    return result

# %%
def loan_emi(amount, duration):
    emi = amount/duration
    return emi

# %%
def loan_emi(amount, duration, down_payment = 0):
    loan_amount = amount - down_payment
    emi = loan_amount/duration
    return emi

# %% [markdown]
# #### Built-in Functions

# %%
len(countries)

# %%
max(numbers)

# %%
min(numbers)

# %%
type(countries)

# %% [markdown]
# ### Module

# %%
import os

# %%
os.getcwd()

# %%
os.listdir()

# %%
os.makedir()

# %% [markdown]
# ### Working with Pandas

# %%
import

# %%
#array
new_data = np.array([[1,5], [5,7], [8,9]])

# %%
df = pd.Dataframe(new_data, index = ['row1', 'row2', 'row3'], columns=['col1'], ['col2'])
df

# %%
# dict
states= ['California', 'Texas', 'NewYork', 'Florida']
Population= [100000, 30097766, 25262782, 25262778]

# %%
dict_states= {"State":states 'Population':Population }

# %%
df1= pd.DataFrame(dict_states)
df1

# %% [markdown]
# #### from csv file

# %%
#new data
covid_df = pd.read_csv('italy-covid-daywise.csv')

# %%
covid_df.info()

# %%
covid_df.describe()

# %%
covid_df.columns

# %%
covid_df.shape

# %%
covid_df.dtypes

# %%
type(covid_df)

# %%
covid_df.head(5)

# %%
covid_df.tail(4)

# %%
covid_df['new_cases'][246]

# %%
#selecting one column
covid_df['date']

# %%
covid_df.date

# %%
cases_df = covid_df[['date', 'new_cases']]
cases_df

# %%
covid_df['new_cases'].sum()

# %%
covid_df['new_cases'].count()
covid_df['new_cases'].mean()
covid_df['new_cases'].std()
covid_df['new_cases'].max()
covid_df['new_cases'].min()

# %%
covid_df_copy = covid_df.copy()

# %%
covid_df.loc[108:113]

# %%
total_cases = covid_df.new_cases.sum()
total_deaths = covid_df.new_deaths.sum()

# %%
death_rate = covid_df.new_deaths.sum() / covid_df.new_cases.sum()

# %%
positive_rate = total_cases / total_tests

# %%
high_new_cases = covid_df.new_cases > 1000

# %%
covid_df[high_new_cases]

# %%
high_cases_df = covid_df[covid_df.new_cases > 1000]

# %%
covid_df['positive_rate'] = covid_df.new_cases / covid_df.new_tests

# %%
covid_df.sort_values('new_cases', ascending=False).head(10)

# %%
covid_df['date'] = pd.to_datetime(covid_df.date)

# %%
covid_df['year'] = pd.DatetimeIndex(covid_df.date).year
covid_df['month'] = pd.DatetimeIndex(covid_df.date).month
covid_df['day'] = pd.DatetimeIndex(covid_df.date).day
covid_df['weekday'] = pd.DatetimeIndex(covid_df.date).weekday

# %%
covid_month_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].sum()

# %%
covid_month_mean_df = covid_df.groupby('month')[['new_cases', 'new_deaths', 'new_tests']].mean()

# %%
locations_df = pd.read_csv('locations.csv')

# %%
locations_df

# %%
locations_df[locations_df.location == "Italy"]

# %%
covid_df['location'] = "Italy"
covid_df

# %%
merged_df = covid_df.merge(locations_df, on="location")

# %%
merged_df['cases_per_million'] = merged_df.total_cases * 1e6 / merged_df.population

# %%
merged_df['deaths_per_million'] = merged_df.total_deaths * 1e6 / merged_df.population

# %%
merged_df['tests_per_million'] = merged_df.total_tests * 1e6 / merged_df.population

# %%
merged_df

# %%
merged_df.to_csv('results.csv', index=None)

# %% [markdown]
# ### Basic Plotting with Pandas

# %%
merged_df.new_cases.plot();

# %%
merged_df.set_index('date', inplace=True)

# %%
merged_df.new_cases.plot()
merged_df.new_deaths.plot();

# %%
merged_df.total_cases.plot()
merged_df.total_deaths.plot();

# %%
death_rate = result_df.total_deaths / result_df.total_cases

# %%
death_rate.plot(title='Death Rate');

# %%
covid_month_df.new_cases.plot(kind='bar');

# %%
covid_month_df.new_tests.plot(kind='bar')
